# %% [markdown]
# ### Made by : <u><i>Shailee R. Desai</i></u>
#
# # Loops
#
# + A programming structutre that implements iteration is called Loops.
# + Iteration : 2 types
#   + Indefinite Iteration
#   + Definite Iteration
#
#
# ## While Loop
#
# + we can execute a set of statements as long as a condition is true.
# + While loop falls under the category of indefinite iteration.
# + Indefinite iteration means that the number of times the loop is executed isn’t specified explicitly in advance.
#
# ## For Loop
#
# + For loops, in general, are used for sequential traversal.
# + It falls under the category of definite iteration.
# + Definite iterations means the number of repetitions is specified explicitly in advance.

# %%
i = 5
while i>1:
    print(i)
    i -=1 # i = i-1
# Out:
# 5
# 4
# 3
# 2

# %%
for i in range(5, 1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2

# %%
fruits = ['apple', 'pineapple', 'banana'] #no index maintaining

while fruits:
    print(fruits.pop())
    print(fruits)
# Out:
# banana
# ['apple', 'pineapple']
# pineapple
# ['apple']
# apple
# []

# %%
fruits = ['apple', 'strawberry', 'pineapple', 'banana'] #based on index
j=0
for fruit in fruits:
    print(j)
    print(fruit)
    
    print(fruits)
    j+=1
# Out:
# 0
# apple
# ['apple', 'strawberry', 'pineapple', 'banana']
# 1
# strawberry
# ['apple', 'strawberry', 'pineapple', 'banana']
# 2
# pineapple
# ['apple', 'strawberry', 'pineapple', 'banana']
# 3
# banana
# ['apple', 'strawberry', 'pineapple', 'banana']

# %% [markdown]
# ## Loop control statements
# ### break statement

# %%
#print fruits till we find 'strawberry' 
fruits = ['apple', 'strawberry', 'pineapple', 'banana']
i = 0
while i<len(fruits):
    if fruits[i]=="strawberry":
        break
    print(fruits[i])
    i+=1
# Out:
# apple

# %%
fruits = ['apple', 'strawberry', 'pineapple', 'banana']
for i in fruits:
#     if i == "strawberry":
#         break
    print(i)
# Out:
# apple
# strawberry
# pineapple
# banana

# %% [markdown]
# ### continue statement

# %%
#print fruits other then 'strawberry' 
fruits = ['apple', 'strawberry', 'pineapple', 'banana']
i = 0
while i<len(fruits):
    if fruits[i]=="strawberry":
        i+=1
        continue
    print(fruits[i])
    i+=1
# Out:
# apple
# pineapple
# banana

# %%
fruits = ['apple', 'strawberry', 'pineapple', 'banana']
for fruit in fruits:
    if fruit == "strawberry":
        continue
    print(fruit)
# Out:
# apple
# pineapple
# banana

# %% [markdown]
# ### Infinite loop in while

# %%
while True:
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %% [markdown]
# ### else statement with while and for loop

# %%
#print fruits till we find 'strawberry' or if strawberry is not present than print "Not Found"
fruits = ['apple', 'strawberry', 'pineapple', 'banana']
i = 0
while i<len(fruits):
    if fruits[i]=="orange":
        break
    print(fruits[i])
    i+=1
else:
    print("Not Found")
# Out:
# apple
# strawberry
# pineapple
# banana
# Not Found

# %%
fruits = ['apple', 'strawberry', 'pineapple', 'banana']
for fruit in fruits:
    if fruit == "guava":
        break
    print(fruit)
else:
    print("Not Found")
# Out:
# apple
# strawberry
# pineapple
# banana
# Not Found

# %% [markdown]
# ### Nested loops

# %%
numbers = [1,2,3]
chars = ['a','b','c']
i = 0

while i< len(numbers):
    j = 0
    while j<len(chars):
        print(numbers[i],chars[j])
        j+=1
    i+=1
# Out:
# 1 a
# 1 b
# 1 c
# 2 a
# 2 b
# 2 c
# 3 a
# 3 b
# 3 c

# %%
numbers = [1, 2, 3]
chars = ["a", "b", "c"]

for x in numbers:
    for y in chars:
        print(x, y)
# Out:
# 1 a
# 1 b
# 1 c
# 2 a
# 2 b
# 2 c
# 3 a
# 3 b
# 3 c
